# %%
import pandas as pd

# %%
ls
# Out:
# Documentation/              book_data_new.csv
# ItemSetFrequencyAnalysis.R  data.csv
# README.md                   data_large.csv
# Study-Report.pdf            newdata.csv
# Untitled.ipynb              server.R
# Untitled1.ipynb             ui.R
# book_data.xlsx

# %%
data = pd.read_csv('data.csv')

# %%
data.head()
# Out:
#    Order ID       Customer Name  Order Date Order Priority      Product Name  \
# 0         3  Muhammed MacIntyre  10/13/2010            Low      citrus fruit
# 1       293        Barry French   10/1/2012           High    tropical fruit
# 2       293        Barry French   10/1/2012           High        whole milk
# 3       483       Clay Rozendal   7/10/2011           High         pip fruit
# 4       515      Carlos Soltero   8/28/2010  Not Specified  other vegetables
#
#    Unit Price  Quantity
# 0       38.94         6
# 1      208.16        49
# 2        8.69        27
# 3      195.99        30
# 4       21.78        19

# %%
temp1 = data

# %%
temp1.head()
# Out:
#    Order ID       Customer Name  Order Date Order Priority      Product Name  \
# 0         3  Muhammed MacIntyre  10/13/2010            Low      citrus fruit
# 1       293        Barry French   10/1/2012           High    tropical fruit
# 2       293        Barry French   10/1/2012           High        whole milk
# 3       483       Clay Rozendal   7/10/2011           High         pip fruit
# 4       515      Carlos Soltero   8/28/2010  Not Specified  other vegetables
#
#    Unit Price  Quantity
# 0       38.94         6
# 1      208.16        49
# 2        8.69        27
# 3      195.99        30
# 4       21.78        19

# %%
temp1['Product Name'].unique()
# Out:
# array(['citrus fruit', 'tropical fruit', 'whole milk', 'pip fruit',
#        'other vegetables', 'rolls/buns', 'pot plants', 'beef',
#        'frankfurter', 'chicken', 'butter', 'fruit/vegetable juice',
#        'packaged fruit/vegetables', 'chocolate', 'specialty bar',
#        'butter milk', 'bottled water', 'yogurt', 'sausage', 'brown bread',
#        'hamburger meat', 'root vegetables', 'pork', 'pastry',
#        'canned beer', 'berries', 'coffee', 'misc. beverages', 'ham',
#        'turkey', 'curd cheese', 'red/blush wine',
#        'frozen potato products', 'flour', 'sugar', 'frozen meals',
#        'herbs', 'soda', 'detergent', 'grapes', 'processed cheese', 'fish',
#        'sparkling wine', 'newspapers', 'curd', 'pasta', 'popcorn',
#        'finished products', 'beverages', 'bottled beer', 'dessert',
#        'dog food', 'specialty chocolate', 'condensed milk', 'cleaner',
#        'white wine', 'meat', 'ice cream', 'hard cheese', 'cream cheese ',
# ...

# %%
def conditions(s):
    if (s['Product Name'] == 'citrus fruit') :
        return 'Egg & Cheese Burger'
    elif (s['Product Name'] == 'tropical fruit'):
        return 'Veggie Egg White Burger'
    elif (s['Product Name'] == 'whole milk'):
        return 'Sausage egg & cheese burger'
    elif (s['Product Name'] == 'pip fruit'):
        return 'Bacon egg & cheese burger'
    elif (s['Product Name'] == 'other vegetables'):
        return 'Turkey Sausage Burger'
    elif (s['Product Name'] == 'rolls/buns'):
        return 'Ham egg & cheese burger'
    elif (s['Product Name'] == 'pot plants'):
        return 'Egg & cheese wrap'
    elif (s['Product Name'] == 'beef'):
        return 'Hot Coffee'
    elif (s['Product Name'] == 'frankfurter'):
        return 'Cold Coffee'
    elif (s['Product Name'] == 'chicken'):
        return 'Hot Chocolate'
    elif (s['Product Name'] == 'butter'):
        return 'Cappuccino'
    elif (s['Product Name'] == 'fruit/vegetable juice'):
        return 'Hot Tea'
    elif (s['Product Name'] == 'packaged fruit/vegetables'):
        return 'Iced Tea'
    elif (s['Product Name'] == 'chocolate'):
        return 'Americano'
    elif (s['Product Name'] == 'specialty bar'):
        return 'Latte'
    elif (s['Product Name'] == 'butter milk'):
        return 'Macchiato'
    elif (s['Product Name'] == 'bottled water'):
        return 'Frozen Chocolate'
    elif (s['site_category'] == 'yogurt'):
        return 'Veggie Egg White Burger'
    elif (s['site_category'] == 'sausage'):
        return 'Sausage egg & cheese burger'
    elif (s['site_category'] == 'brown bread'):
        return 'Bacon egg & cheese burger'
    elif (s['site_category'] == 'hamburger meat'):
        return 'Turkey Sausage Burger'
    elif (s['site_category'] == 'root vegetables'):
        return 'Ham egg & cheese burger'
    elif (s['site_category'] == 'pork'):
        return 'Egg & cheese wrap'
    elif (s['site_category'] == 'pastry'):
        return 'Hot Coffee'
    elif (s['site_category'] == 'canned beer'):
        return 'Cold Coffee'
    elif (s['site_category'] == 'berries'):
        return 'Hot Chocolate'
    elif (s['site_category'] == 'coffee'):
        return 'Cappuccino'
    elif (s['site_category'] == 'misc. beverages'):
        return 'Hot Tea'
    elif (s['site_category'] == 'ham'):
        return 'Iced Tea'
    elif (s['site_category'] == 'turkey'):
        return 'Americano'
    elif (s['site_category'] == 'curd cheese'):
        return 'Latte'
    elif (s['site_category'] == 'red/blush wine'):
        return 'Macchiato'
    elif (s['site_category'] == 'frozen potato products'):
        return 'Frozen Chocolate'
    elif (s['site_category'] == 'flour'):
        return 'Veggie Egg White Burger'
    elif (s['site_category'] == 'sugar'):
        return 'Sausage egg & cheese burger'
    elif (s['site_category'] == 'frozen meals'):
        return 'Bacon egg & cheese burger'
    elif (s['site_category'] == 'herbs'):
        return 'Turkey Sausage Burger'
    elif (s['site_category'] == 'soda'):
        return 'Ham egg & cheese burger'
    elif (s['site_category'] == 'detergent'):
        return 'Egg & cheese wrap'
    elif (s['site_category'] == 'grapes'):
        return 'Hot Coffee'
    elif (s['site_category'] == 'processed cheese'):
        return 'Cold Coffee'
    elif (s['site_category'] == 'fish'):
        return 'Hot Chocolate'
    elif (s['site_category'] == 'sparkling wine'):
        return 'Cappuccino'
    elif (s['site_category'] == 'newspapers'):
        return 'Hot Tea'
    elif (s['site_category'] == 'curd'):
        return 'Iced Tea'
    elif (s['site_category'] == 'pasta'):
        return 'Americano'
    elif (s['site_category'] == 'popcorn'):
        return 'Latte'
    elif (s['site_category'] == 'finished products'):
        return 'Macchiato'
    elif (s['site_category'] == 'beverages'):
        return 'Frozen Chocolate'
    elif (s['site_category'] == 'bottled beer'):
        return 'Veggie Egg White Burger'
    elif (s['site_category'] == 'dessert'):
        return 'Sausage egg & cheese burger'
    elif (s['site_category'] == 'dog food'):
        return 'Bacon egg & cheese burger'
    elif (s['site_category'] == 'specialty chocolate'):
        return 'Turkey Sausage Burger'
    elif (s['site_category'] == 'condensed milk'):
        return 'Ham egg & cheese burger'
    elif (s['site_category'] == 'cleaner'):
        return 'Egg & cheese wrap'
    elif (s['site_category'] == 'white wine'):
        return 'Hot Coffee'
    elif (s['site_category'] == 'meat'):
        return 'Cold Coffee'
    elif (s['site_category'] == 'ice cream'):
        return 'Hot Chocolate'
    elif (s['site_category'] == 'hard cheese'):
        return 'Cappuccino'
    elif (s['site_category'] == 'cream cheese '):
        return 'Hot Tea'
    elif (s['site_category'] == 'liquor'):
        return 'Iced Tea'
    elif (s['site_category'] == 'pickled vegetables'):
        return 'Americano'
    elif (s['site_category'] == 'liquor (appetizer)'):
        return 'Latte'
    elif (s['site_category'] == 'UHT-milk'):
        return 'Macchiato'
    elif (s['site_category'] == 'candy'):
        return 'Frozen Chocolate'
    elif (s['site_category'] == 'onions'):
        return 'Veggie Egg White Burger'
    elif (s['site_category'] == 'hair spray'):
        return 'Sausage egg & cheese burger'
    elif (s['site_category'] == 'photo/film'):
        return 'Bacon egg & cheese burger'
    elif (s['site_category'] == 'domestic eggs'):
        return 'Turkey Sausage Burger'
    elif (s['site_category'] == 'margarine'):
        return 'Ham egg & cheese burger'
    elif (s['site_category'] == 'shopping bags'):
        return 'Egg & cheese wrap'
    elif (s['site_category'] == 'salt'):
        return 'Hot Coffee'
    elif (s['site_category'] == 'oil'):
        return 'Cold Coffee'
    elif (s['site_category'] == 'whipped/sour cream'):
        return 'Hot Chocolate'
    elif (s['site_category'] == 'frozen vegetables'):
        return 'Cappuccino'
    elif (s['site_category'] == 'sliced cheese'):
        return 'Hot Tea'
    elif (s['site_category'] == 'dish cleaner'):
        return 'Iced Tea'
    elif (s['site_category'] == 'baking powder'):
        return 'Americano'
    elif (s['site_category'] == 'specialty cheese'):
        return 'Latte'
    elif (s['site_category'] == 'salty snack'):
        return 'Macchiato'
    elif (s['site_category'] == 'Instant food products'):
        return 'Frozen Chocolate'
    elif (s['site_category'] == 'pet care'):
        return 'Veggie Egg White Burger'
    elif (s['site_category'] == 'white bread'):
        return 'Sausage egg & cheese burger'
    elif (s['site_category'] == 'female sanitary products'):
        return 'Bacon egg & cheese burger'
    elif (s['site_category'] == 'cling film/bags'):
        return 'Turkey Sausage Burger'
    elif (s['site_category'] == 'soap'):
        return 'Ham egg & cheese burger'
    elif (s['site_category'] == 'frozen chicken'):
        return 'Egg & cheese wrap'
    elif (s['site_category'] == 'house keeping products'):
        return 'Hot Coffee'
    elif (s['site_category'] == 'spread cheese'):
        return 'Cold Coffee'
    elif (s['site_category'] == 'decalcifier'):
        return 'Hot Chocolate'
    elif (s['site_category'] == 'frozen dessert'):
        return 'Cappuccino'
    elif (s['site_category'] == 'vinegar'):
        return 'Hot Tea'
    elif (s['site_category'] == 'nuts/prunes'):
        return 'Iced Tea'
    elif (s['site_category'] == 'potato products'):
        return 'Americano'
    elif (s['site_category'] == 'frozen fish'):
        return 'Latte'
    elif (s['site_category'] == 'hygiene articles'):
        return 'Macchiato'
    elif (s['site_category'] == 'artif. sweetener'):
        return 'Frozen Chocolate'
    else:
        return 'Others'
